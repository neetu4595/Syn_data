# %%
# %cd C:\Users\neetu\Documents\Untitled_Folder\tabsyn
# Out:
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn
# C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install dgl
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install peft
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install datasets
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install torch_geometric
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# install other dependencies
# !pip install -r requirements.txt
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# Create a directory for the dataset
#%cd $current_dir/data
# %mkdir data\heart

# %%
import json

metadata = {
    "name": "heart",
    "task_type": "binclass",  # binclass or regression or multiclass
    "header": "infer",
    "column_names": None,
    "num_col_idx": [1, 3, 5, 9, 10],  # list of indices of numerical columns
    "cat_col_idx": [0, 2, 4, 6, 7, 8, 11],  # list of indices of categorical columns
    "target_col_idx": [12],  # list of indices of the target columns (for MLE)
    "file_type": "csv",
    "data_path": f"data/heart/heart.csv",
    "test_path": None,
}

# %%
# Save the metadata as a JSON file
with open("C:\\Users\\neetu\\Documents\\Untitled_Folder\\tabsyn\\data\\Info\\heart.json", "w") as json_file:
    json.dump(metadata, json_file, indent=4)

# %%
# !python download_dataset.py
# Out:
# Start processing dataset obesity from UCI.
# Aready downloaded.

# %%
! python process_dataset.py
# Out:
# adult (32561, 15) (16281, 15) (32561, 15)
# Numerical (32561, 6)
# Categorical (32561, 8)
# Processing and Saving adult Successfully!
# adult
# Total 48842
# Train 32561
# Test 16281
# Num 6
# Cat 9
# default (27000, 24) (3000, 24) (30000, 24)
# Numerical (27000, 14)
# Categorical (27000, 9)
# Processing and Saving default Successfully!
# default
# Total 30000
# Train 27000
# Test 3000
# Num 14
# Cat 10
# shoppers (11097, 18) (1233, 18) (12330, 18)
# Numerical (11097, 10)
# Categorical (11097, 7)
# Processing and Saving shoppers Successfully!
# shoppers
# Total 12330
# Train 11097
# Test 1233
# Num 10
# Cat 8
# magic (17117, 11) (1902, 11) (19019, 11)
# Numerical (17117, 10)
# Categorical (17117, 0)
# Processing and Saving magic Successfully!
# magic
# Total 19019
# Train 17117
# Test 1902
# Num 10
# Cat 1
# beijing (37581, 12) (4176, 12) (41757, 12)
# Numerical (37581, 6)
# Categorical (37581, 5)
# Processing and Saving beijing Successfully!
# beijing
# Total 41757
# Train 37581
# ...

# %%
# %%writefile C:/Users/neetu/Documents/Untitled_Folder/tabsyn/baselines/tabddpm/configs/heart.toml
# # Sample TOML file for insurance configuration
#
# parent_dir = "configs/heart"
# model_save_path = "ckpt/heart"
# sample_save_path = "sampled/heart"
# real_data_path = "Data/heart"
#
# num_numerical_features = 5
# model_type = "mlp"
# task_type = "binclass"  #changed from "binclass" to "multiclass"
#
# [model_params]
# num_classes = 2
# is_y_cond = false
#
# [model_params.rtdl_params]
# d_layers = [
#     1024,
#     2048,
#     2048,
#     1024,
# ]
# dropout = 0.0
#
# [diffusion_params]
# num_timesteps = 1000
# gaussian_loss_type = "mse"
#
# [train.main]
# steps = 1000 #changed from 100000 to 100 for understanding
# lr = 0.001809824563637657
# weight_decay = 5e-4
# batch_size = 4096
#
# [train.T]
# seed = 0
# normalization = "quantile"
# num_nan_policy = "mean"
# cat_nan_policy = "__none__"
# cat_min_frequency = "__none__"
# cat_encoding = "__none__"
# y_policy = "default"
#
# [sample]
# num_samples = 4500
# batch_size = 1000
# seed = 0
#
# [eval.type]
# eval_model = "mlp"
# eval_type = "synthetic"
#
# [eval.T]
# seed = 0
# normalization = "quantile"
# num_nan_policy = "__none__"
# cat_nan_policy = "__none__"
# cat_min_frequency = "__none__"
# cat_encoding = "one-hot"
# y_policy = "default"
# Out:
# Overwriting C:/Users/neetu/Documents/Untitled_Folder/tabsyn/baselines/tabddpm/configs/heart.toml

# %%
# train Tabddpm model for "insurance" dataset
# !python main.py --dataname heart --method tabddpm --mode train
# Out:
# START TRAINING
# No NaNs in numerical features, skipping
# 790
# {'num_classes': 2, 'is_y_cond': False, 'rtdl_params': {'d_layers': [1024, 2048, 2048, 1024], 'dropout': 0.0}, 'd_in': 790}
# mlp
# MLPDiffusion(
#   (mlp): MLP(
#     (blocks): ModuleList(
#       (0): Block(
#         (linear): Linear(in_features=1024, out_features=1024, bias=True)
#         (activation): ReLU()
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (1): Block(
#         (linear): Linear(in_features=1024, out_features=2048, bias=True)
#         (activation): ReLU()
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (2): Block(
#         (linear): Linear(in_features=2048, out_features=2048, bias=True)
#         (activation): ReLU()
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (3): Block(
#         (linear): Linear(in_features=2048, out_features=1024, bias=True)
#         (activation): ReLU()
#         (dropout): Dropout(p=0.0, inplace=False)
# ...

# %%
# train VAE first
# !python main.py --dataname heart --method vae --mode train
# Out:
# No NaNs in numerical features, skipping
# self.category_embeddings.weight.shape=torch.Size([785, 4])
# self.category_embeddings.weight.shape=torch.Size([785, 4])
# epoch: 0, beta = 0.010000, Train MSE: 36.123831, Train CE:3.903475, Train KL:0.869735, Val MSE:33.187588, Val CE:3.885887, Train ACC:0.082921, Val ACC:0.092000
# epoch: 1, beta = 0.010000, Train MSE: 33.494508, Train CE:3.884233, Train KL:0.817580, Val MSE:30.756130, Val CE:3.872472, Train ACC:0.087562, Val ACC:0.097250
# epoch: 2, beta = 0.010000, Train MSE: 30.913007, Train CE:3.874684, Train KL:0.794226, Val MSE:28.399403, Val CE:3.863329, Train ACC:0.099629, Val ACC:0.092500
# epoch: 3, beta = 0.010000, Train MSE: 28.402906, Train CE:3.865262, Train KL:0.794616, Val MSE:25.959314, Val CE:3.849497, Train ACC:0.096535, Val ACC:0.101500
# epoch: 4, beta = 0.010000, Train MSE: 26.119021, Train CE:3.855894, Train KL:0.815784, Val MSE:23.807678, Val CE:3.855874, Train ACC:0.103032, Val ACC:0.100000
# ...

# %%
# after the VAE is trained, train the diffusion model
# !python main.py --dataname heart --method tabsyn --mode train
# Out:
# ...
# Epoch 1/1001: 100%|##########| 2/2 [00:13<00:00,  6.53s/it, Loss=3.78]
#
# ...
# Epoch 2/1001: 100%|##########| 2/2 [00:13<00:00,  6.85s/it, Loss=4.36]
#
# ...
# Epoch 3/1001: 100%|##########| 2/2 [00:13<00:00,  6.85s/it, Loss=3.16]
#
# ...
# Epoch 4/1001: 100%|##########| 2/2 [00:14<00:00,  7.21s/it, Loss=3.38]
#
# ...
# Epoch 5/1001: 100%|##########| 2/2 [00:14<00:00,  7.13s/it, Loss=2.95]
#
# ...
# Epoch 6/1001: 100%|##########| 2/2 [00:13<00:00,  6.86s/it, Loss=2.54]
#
# ...
# Epoch 7/1001: 100%|##########| 2/2 [00:14<00:00,  7.35s/it, Loss=2.55]
#
# ...
# Epoch 8/1001: 100%|##########| 2/2 [00:15<00:00,  7.51s/it, Loss=2.52]
#
# ...
# Epoch 9/1001: 100%|##########| 2/2 [00:15<00:00,  7.70s/it, Loss=2.26]
#
# ...
# Epoch 10/1001: 100%|##########| 2/2 [00:15<00:00,  7.89s/it, Loss=2.14]
#
# ...
# Epoch 11/1001: 100%|##########| 2/2 [00:15<00:00,  7.85s/it, Loss=2.15]
#
# ...
# Epoch 12/1001: 100%|##########| 2/2 [00:16<00:00,  8.34s/it, Loss=1.87]
#
# ...
# Epoch 13/1001: 100%|##########| 2/2 [00:16<00:00,  8.27s/it, Loss=1.9]
#
# ...

# %%
#Generating the synthetic data by trained tabddpm model and saving it to synthetic/heart/tabppm.csv
# !python main.py --dataname heart --method tabddpm --mode sample --save_path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabddpm.csv
# Out:
# START SAMPLING
# No NaNs in numerical features, skipping
# mlp
# torch.Size([1000, 785])
# Sample timestep  999
# Sample timestep  998
# Sample timestep  997
# Sample timestep  996
# Sample timestep  995
# Sample timestep  994
# Sample timestep  993
# Sample timestep  992
# Sample timestep  991
# Sample timestep  990
# Sample timestep  989
# Sample timestep  988
# Sample timestep  987
# Sample timestep  986
# Sample timestep  985
# Sample timestep  984
# Sample timestep  983
# Sample timestep  982
# Sample timestep  981
# Sample timestep  980
# Sample timestep  979
# Sample timestep  978
# Sample timestep  977
# Sample timestep  976
# Sample timestep  975
# Sample timestep  974
# Sample timestep  973
# Sample timestep  972
# Sample timestep  971
# Sample timestep  970
# Sample timestep  969
# Sample timestep  968
# Sample timestep  967
# Sample timestep  966
# Sample timestep  965
# Sample timestep  964
# Sample timestep  963
# Sample timestep  962
# Sample timestep  961
# ...

# %%
# Generating synthetic data by trained tabsyn model and saving it to synthetic/heart/tabsyn.csv
# !python main.py --dataname heart --method tabsyn --mode sample --save_path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabsyn.csv
# Out:
# No NaNs in numerical features, skipping
# (4500, 8)
# Time: 2.773077964782715
# Saving sampled data to C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabsyn.csv

# %%
# !python eval/eval_density.py --dataname heart --model tabddpm --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabddpm.csv
# Out:
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabddpm.csv
# Generating report ...
#
# ...
# (1/2) Evaluating Column Shapes: : 100%|##########| 13/13 [00:00<00:00, 254.78it/s]
#
# ...
# (2/2) Evaluating Column Pair Trends: : 100%|##########| 78/78 [00:04<00:00, 16.99it/s]
#
# Overall Quality Score: 43.61%
#
# Properties:
# - Column Shapes: 54.12%
# - Column Pair Trends: 33.1%
# Generating report ...
#
# ...
# (1/3) Evaluating Coverage: : 100%|##########| 13/13 [00:00<00:00, 806.58it/s]
#
# ...
# (2/3) Evaluating Boundary: : 100%|##########| 13/13 [00:00<?, ?it/s]
#
# ...
# (3/3) Evaluating Synthesis: : 100%|##########| 1/1 [00:00<?, ?it/s]
#
# Diagnostic Results:
#
# SUCCESS:
# Traceback (most recent call last):
#   File "C:\Users\neetu\Documents\Untitled_Folder\tabsyn\eval\eval_density.py", line 99, in <module>
#     diag_report.generate(new_real_data, new_syn_data, metadata)
#   File "C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sdmetrics\reports\base_report.py", line 155, in generate
# ...

# %%
# !python eval/eval_density.py --dataname heart --model tabsyn --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabsyn.csv
# Out:
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabsyn.csv
# Generating report ...
#
# ...
# (1/2) Evaluating Column Shapes: : 100%|##########| 13/13 [00:00<00:00, 270.44it/s]
#
# ...
# (2/2) Evaluating Column Pair Trends: : 100%|##########| 78/78 [00:05<00:00, 14.19it/s]
#
# Overall Quality Score: 80.87%
#
# Properties:
# - Column Shapes: 90.13%
# - Column Pair Trends: 71.61%
# Generating report ...
#
# ...
# (1/3) Evaluating Coverage: : 100%|##########| 13/13 [00:00<?, ?it/s]
#
# ...
# (2/3) Evaluating Boundary: : 100%|##########| 13/13 [00:00<00:00, 792.71it/s]
#
# ...
# (3/3) Evaluating Synthesis: : 100%|##########| 1/1 [00:00<?, ?it/s]
#
# Diagnostic Results:
#
# SUCCESS:
# Traceback (most recent call last):
#   File "C:\Users\neetu\Documents\Untitled_Folder\tabsyn\eval\eval_density.py", line 99, in <module>
#     diag_report.generate(new_real_data, new_syn_data, metadata)
#   File "C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sdmetrics\reports\base_report.py", line 155, in generate
# ...

# %%
# !python eval/eval_quality.py --dataname heart --model tabddpm --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabddpm.csv
# Out:
# [KeOps] Warning :
#     The default C++ compiler could not be found on your system.
#     You need to either define the CXX environment variable or a symlink to the g++ command.
#     For example if g++-8 is the command you can do
#       import os
#       os.environ['CXX'] = 'g++-8'
#
# [KeOps] Warning : Cuda libraries were not detected on the system or could not be loaded ; using cpu only mode
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabddpm.csv
# =========== All Features ===========
# Data shape:  (4500, 790)
# alpha precision: 0.528830, beta recall: 0.001170

# %%
# !python eval/eval_quality.py --dataname heart --model tabsyn --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabsyn.csv
# Out:
# [KeOps] Warning :
#     The default C++ compiler could not be found on your system.
#     You need to either define the CXX environment variable or a symlink to the g++ command.
#     For example if g++-8 is the command you can do
#       import os
#       os.environ['CXX'] = 'g++-8'
#
# [KeOps] Warning : Cuda libraries were not detected on the system or could not be loaded ; using cpu only mode
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabsyn.csv
# =========== All Features ===========
# Data shape:  (4500, 790)
# alpha precision: 0.838904, beta recall: 0.221511

# %%
# !python eval/eval_mle.py --dataname heart --model tabddpm --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabddpm.csv
# Out:
# Saving scores to  eval/mle/heart/tabddpm.json
# ...
# 100%|##########| 48/48 [00:03<00:00, 12.43it/s]
#
# ...
# 100%|##########| 4/4 [00:08<00:00,  2.22s/it]
#
# ...
#   6%|5         | 2/36 [00:01<00:31,  1.06it/s]C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#
# ...
#  36%|###6      | 13/36 [00:12<00:22,  1.00it/s]C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
# !python eval/eval_mle.py --dataname heart --model tabsyn --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabsyn.csv
# Out:
# Saving scores to  eval/mle/heart/tabsyn.json
# ...
# 100%|##########| 48/48 [00:08<00:00,  5.57it/s]
#
# ...
# 100%|##########| 4/4 [00:16<00:00,  4.17s/it]
#
# ...
#   3%|2         | 1/36 [00:01<00:49,  1.40s/it]C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#
#   6%|5         | 2/36 [00:02<00:41,  1.23s/it]C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
# !python eval/eval_dcr.py --dataname heart --model tabddpm --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabddpm.csv
# Out:
# DCR Score, a value closer to 0.5 is better
# heart-tabddpm, DCR Score = 0.4268888888888889

# %%
# !python eval/eval_dcr.py --dataname heart --model tabsyn --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\heart\tabsyn.csv
# Out:
# DCR Score, a value closer to 0.5 is better
# heart-tabsyn, DCR Score = 0.3808888888888889
