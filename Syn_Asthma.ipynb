# %%
# %cd C:\Users\neetu\Documents\Untitled_Folder\tabsyn
# Out:
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn

# %%
# !pip install dgl
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install peft
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install datasets
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install torch_geometric
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# install other dependencies
# !pip install -r requirements.txt
# Out:
# ...
# DEPRECATION: xgbse 0.2.3 has a non-standard dependency specifier pandas>=1.0.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of xgbse or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# Create a directory for the dataset
#%cd $current_dir/asthma
# %mkdir data\asthma

# %%
import json

metadata = {
    "name": "asthma",
    "task_type": "binclass",  # binclass or regression or multiclass
    "header": "infer",
    "column_names": None,
    "num_col_idx": [0, 5],  # list of indices of numerical columns
    "cat_col_idx": [1, 2, 4],  # list of indices of categorical columns
    "target_col_idx": [3],  # list of indices of the target columns (for MLE)
    "file_type": "csv",
    "data_path": f"data/asthma/asthma.csv",
    "test_path": None,
}

# %%
# Save the metadata as a JSON file
with open("C:\\Users\\neetu\\Documents\\Untitled_Folder\\tabsyn\\data\\Info\\asthma.json", "w") as json_file:
    json.dump(metadata, json_file, indent=4)

# %%
# !python download_dataset.py
# Out:
# Start processing dataset obesity from UCI.
# Aready downloaded.

# %%
! python process_dataset.py
# Out:
# adult (32561, 15) (16281, 15) (32561, 15)
# Numerical (32561, 6)
# Categorical (32561, 8)
# Processing and Saving adult Successfully!
# adult
# Total 48842
# Train 32561
# Test 16281
# Num 6
# Cat 9
# default (27000, 24) (3000, 24) (30000, 24)
# Numerical (27000, 14)
# Categorical (27000, 9)
# Processing and Saving default Successfully!
# default
# Total 30000
# Train 27000
# Test 3000
# Num 14
# Cat 10
# shoppers (11097, 18) (1233, 18) (12330, 18)
# Numerical (11097, 10)
# Categorical (11097, 7)
# Processing and Saving shoppers Successfully!
# shoppers
# Total 12330
# Train 11097
# Test 1233
# Num 10
# Cat 8
# magic (17117, 11) (1902, 11) (19019, 11)
# Numerical (17117, 10)
# Categorical (17117, 0)
# Processing and Saving magic Successfully!
# magic
# Total 19019
# Train 17117
# Test 1902
# Num 10
# Cat 1
# beijing (37581, 12) (4176, 12) (41757, 12)
# Numerical (37581, 6)
# Categorical (37581, 5)
# Processing and Saving beijing Successfully!
# beijing
# Total 41757
# Train 37581
# ...

# %%
# %%writefile C:/Users/neetu/Documents/Untitled_Folder/tabsyn/baselines/tabddpm/configs/asthma.toml
# # Sample TOML file for age configuration
#
# parent_dir = "configs/asthma"
# model_save_path = "ckpt/asthma"
# sample_save_path = "sampled/asthma"
# real_data_path = "Data/asthma"
#
# num_numerical_features = 2
# model_type = "mlp"
# task_type = "binclass"  #changed from "binclass" to "multiclass"
#
# [model_params]
# num_classes = 2
# is_y_cond = false
#
# [model_params.rtdl_params]
# d_layers = [
#     1024,
#     2048,
#     2048,
#     1024,
# ]
# dropout = 0.0
#
# [diffusion_params]
# num_timesteps = 1000
# gaussian_loss_type = "mse"
#
# [train.main]
# steps = 1000 #changed from 100000 to 100 for understanding
# lr = 0.001809824563637657
# weight_decay = 5e-4
# batch_size = 4096
#
# [train.T]
# seed = 0
# normalization = "quantile"
# num_nan_policy = "mean"
# cat_nan_policy = "__none__"
# cat_min_frequency = "__none__"
# cat_encoding = "__none__"
# y_policy = "default"
#
# [sample]
# num_samples = 270
# batch_size = 1000
# seed = 0
#
# [eval.type]
# eval_model = "mlp"
# eval_type = "synthetic"
#
# [eval.T]
# seed = 0
# normalization = "quantile"
# num_nan_policy = "__none__"
# cat_nan_policy = "__none__"
# cat_min_frequency = "__none__"
# cat_encoding = "one-hot"
# y_policy = "default"
# Out:
# Writing C:/Users/neetu/Documents/Untitled_Folder/tabsyn/baselines/tabddpm/configs/asthma.toml

# %%
# train Tabddpm model for "age" dataset
# !python main.py --dataname asthma --method tabddpm --mode train
# Out:
# START TRAINING
# No NaNs in numerical features, skipping
# 12
# {'num_classes': 2, 'is_y_cond': False, 'rtdl_params': {'d_layers': [1024, 2048, 2048, 1024], 'dropout': 0.0}, 'd_in': 12}
# mlp
# MLPDiffusion(
#   (mlp): MLP(
#     (blocks): ModuleList(
#       (0): Block(
#         (linear): Linear(in_features=1024, out_features=1024, bias=True)
#         (activation): ReLU()
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (1): Block(
#         (linear): Linear(in_features=1024, out_features=2048, bias=True)
#         (activation): ReLU()
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (2): Block(
#         (linear): Linear(in_features=2048, out_features=2048, bias=True)
#         (activation): ReLU()
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (3): Block(
#         (linear): Linear(in_features=2048, out_features=1024, bias=True)
#         (activation): ReLU()
#         (dropout): Dropout(p=0.0, inplace=False)
# ...

# %%
# train VAE first
# !python main.py --dataname asthma --method vae --mode train
# Out:
# No NaNs in numerical features, skipping
# self.category_embeddings.weight.shape=torch.Size([10, 4])
# self.category_embeddings.weight.shape=torch.Size([10, 4])
# epoch: 0, beta = 0.010000, Train MSE: 5.052323, Train CE:1.173241, Train KL:0.305148, Val MSE:4.637945, Val CE:1.135464, Train ACC:0.426852, Val ACC:0.466667
# epoch: 1, beta = 0.010000, Train MSE: 4.722702, Train CE:1.094227, Train KL:0.274394, Val MSE:4.288328, Val CE:1.234893, Train ACC:0.461111, Val ACC:0.425000
# epoch: 2, beta = 0.010000, Train MSE: 4.329080, Train CE:1.131598, Train KL:0.253741, Val MSE:4.635071, Val CE:1.057086, Train ACC:0.433333, Val ACC:0.483333
# epoch: 3, beta = 0.010000, Train MSE: 3.758047, Train CE:1.069938, Train KL:0.242265, Val MSE:3.552968, Val CE:1.137687, Train ACC:0.443519, Val ACC:0.400000
# epoch: 4, beta = 0.010000, Train MSE: 3.342802, Train CE:1.109841, Train KL:0.238081, Val MSE:2.892190, Val CE:1.137802, Train ACC:0.395370, Val ACC:0.416667
# ...

# %%
# after the VAE is trained, train the diffusion model
# !python main.py --dataname asthma --method tabsyn --mode train
# Out:
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\tabsyn/ckpt/asthma/
# MLPDiffusion(
#   (proj): Linear(in_features=24, out_features=1024, bias=True)
#   (mlp): Sequential(
#     (0): Linear(in_features=1024, out_features=2048, bias=True)
#     (1): SiLU()
#     (2): Linear(in_features=2048, out_features=2048, bias=True)
#     (3): SiLU()
#     (4): Linear(in_features=2048, out_features=1024, bias=True)
#     (5): SiLU()
#     (6): Linear(in_features=1024, out_features=24, bias=True)
#   )
#   (map_noise): PositionalEmbedding()
#   (time_embed): Sequential(
#     (0): Linear(in_features=1024, out_features=1024, bias=True)
#     (1): SiLU()
#     (2): Linear(in_features=1024, out_features=1024, bias=True)
#   )
# )
# the number of parameters 10543128
# Time:  11574.54151058197
# ...
# Epoch 1/1001: 100%|##########| 1/1 [00:30<00:00, 30.01s/it, Loss=1.19]
#
# ...
# Epoch 2/1001: 100%|##########| 1/1 [00:23<00:00, 23.49s/it, Loss=1.12]
#
# ...

# %%
#Generating the synthetic data by trained tabddpm model and saving it to synthetic/age/tabppm.csv
# !python main.py --dataname asthma --method tabddpm --mode sample --save_path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabddpm.csv
# Out:
# START SAMPLING
# No NaNs in numerical features, skipping
# mlp
# torch.Size([1000, 10])
# Sample timestep  999
# Sample timestep  998
# Sample timestep  997
# Sample timestep  996
# Sample timestep  995
# Sample timestep  994
# Sample timestep  993
# Sample timestep  992
# Sample timestep  991
# Sample timestep  990
# Sample timestep  989
# Sample timestep  988
# Sample timestep  987
# Sample timestep  986
# Sample timestep  985
# Sample timestep  984
# Sample timestep  983
# Sample timestep  982
# Sample timestep  981
# Sample timestep  980
# Sample timestep  979
# Sample timestep  978
# Sample timestep  977
# Sample timestep  976
# Sample timestep  975
# Sample timestep  974
# Sample timestep  973
# Sample timestep  972
# Sample timestep  971
# Sample timestep  970
# Sample timestep  969
# Sample timestep  968
# Sample timestep  967
# Sample timestep  966
# Sample timestep  965
# Sample timestep  964
# Sample timestep  963
# Sample timestep  962
# Sample timestep  961
# ...

# %%
# Generating synthetic data by trained tabsyn model and saving it to synthetic/age/tabsyn.csv
# !python main.py --dataname asthma --method tabsyn --mode sample --save_path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabsyn.csv
# Out:
# No NaNs in numerical features, skipping
# (270, 4)
# Time: 1.186152458190918
# Saving sampled data to C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabsyn.csv

# %%
# !python eval/eval_density.py --dataname asthma --model tabddpm --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabddpm.csv
# Out:
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabddpm.csv
# Generating report ...
#
# ...
# (1/2) Evaluating Column Shapes: : 100%|##########| 6/6 [00:00<00:00, 581.49it/s]
#
# ...
# (2/2) Evaluating Column Pair Trends: : 100%|##########| 15/15 [00:00<00:00, 33.19it/s]
#
# Overall Quality Score: 31.93%
#
# Properties:
# - Column Shapes: 47.1%
# - Column Pair Trends: 16.76%
# Generating report ...
#
# ...
# (1/3) Evaluating Coverage: : 100%|##########| 6/6 [00:00<00:00, 542.21it/s]
#
# ...
# (2/3) Evaluating Boundary: : 100%|##########| 6/6 [00:00<00:00, 2296.99it/s]
#
# ...
# (3/3) Evaluating Synthesis: : 100%|##########| 1/1 [00:00<00:00, 179.24it/s]
#
# Diagnostic Results:
#
# SUCCESS:
# Traceback (most recent call last):
#   File "C:\Users\neetu\Documents\Untitled_Folder\tabsyn\eval\eval_density.py", line 99, in <module>
#     diag_report.generate(new_real_data, new_syn_data, metadata)
# ...

# %%
# !python eval/eval_density.py --dataname asthma --model tabsyn --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabsyn.csv
# Out:
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabsyn.csv
# Generating report ...
#
# ...
# (1/2) Evaluating Column Shapes: : 100%|##########| 6/6 [00:00<00:00, 239.94it/s]
#
# ...
# (2/2) Evaluating Column Pair Trends: : 100%|##########| 15/15 [00:00<00:00, 51.30it/s]
#
# Overall Quality Score: 90.44%
#
# Properties:
# - Column Shapes: 93.4%
# - Column Pair Trends: 87.49%
# Generating report ...
#
# ...
# (1/3) Evaluating Coverage: : 100%|##########| 6/6 [00:00<00:00, 924.06it/s]
#
# ...
# (2/3) Evaluating Boundary: : 100%|##########| 6/6 [00:00<?, ?it/s]
#
# ...
# (3/3) Evaluating Synthesis: : 100%|##########| 1/1 [00:00<00:00, 414.29it/s]
#
# Diagnostic Results:
#
# SUCCESS:
# Traceback (most recent call last):
#   File "C:\Users\neetu\Documents\Untitled_Folder\tabsyn\eval\eval_density.py", line 99, in <module>
#     diag_report.generate(new_real_data, new_syn_data, metadata)
# ...

# %%
# !python eval/eval_quality.py --dataname asthma --model tabddpm --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabddpm.csv
# Out:
# [KeOps] Warning :
#     The default C++ compiler could not be found on your system.
#     You need to either define the CXX environment variable or a symlink to the g++ command.
#     For example if g++-8 is the command you can do
#       import os
#       os.environ['CXX'] = 'g++-8'
#
# [KeOps] Warning : Cuda libraries were not detected on the system or could not be loaded ; using cpu only mode
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabddpm.csv
# =========== All Features ===========
# Data shape:  (270, 12)
# alpha precision: 0.551750, beta recall: 0.000000

# %%
# !python eval/eval_quality.py --dataname asthma --model tabsyn --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabsyn.csv
# Out:
# [KeOps] Warning :
#     The default C++ compiler could not be found on your system.
#     You need to either define the CXX environment variable or a symlink to the g++ command.
#     For example if g++-8 is the command you can do
#       import os
#       os.environ['CXX'] = 'g++-8'
#
# [KeOps] Warning : Cuda libraries were not detected on the system or could not be loaded ; using cpu only mode
# C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabsyn.csv
# =========== All Features ===========
# Data shape:  (270, 12)
# alpha precision: 0.903516, beta recall: 0.618765

# %%
# !python eval/eval_mle.py --dataname asthma --model tabddpm --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabddpm.csv
# Out:
# Traceback (most recent call last):
#   File "C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\utils\_encode.py", line 225, in _encode
#     return _map_to_integer(values, uniques)
#   File "C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\utils\_encode.py", line 165, in _map_to_integer
#     return np.array([table[v] for v in values])
#   File "C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\utils\_encode.py", line 165, in <listcomp>
#     return np.array([table[v] for v in values])
#   File "C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\utils\_encode.py", line 159, in __missing__
#     raise KeyError(key)
# KeyError: 'No'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\neetu\Documents\Untitled_Folder\tabsyn\eval\eval_mle.py", line 62, in <module>
# ...

# %%
# !python eval/eval_mle.py --dataname asthma --model tabsyn --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabsyn.csv
# Out:
# Saving scores to  eval/mle/asthma/tabsyn.json
# ...
# 100%|##########| 48/48 [00:00<00:00, 52.73it/s]
#
# ...
# 100%|##########| 4/4 [00:00<00:00, 42.60it/s]
#
# ...
#   3%|2         | 1/36 [00:01<01:00,  1.71s/it]C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#
#   6%|5         | 2/36 [00:02<00:41,  1.22s/it]C:\Users\neetu\anaconda3\envs\tab\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
# !python eval/eval_dcr.py --dataname asthma --model tabddpm --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabddpm.csv
# Out:
# DCR Score, a value closer to 0.5 is better
# asthma-tabddpm, DCR Score = 1.0

# %%
# !python eval/eval_dcr.py --dataname asthma --model tabsyn --path C:\Users\neetu\Documents\Untitled_Folder\tabsyn\synthetic\asthma\tabsyn.csv
# Out:
# DCR Score, a value closer to 0.5 is better
# asthma-tabsyn, DCR Score = 0.9185185185185185
